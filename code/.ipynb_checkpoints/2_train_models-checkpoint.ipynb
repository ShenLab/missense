# %%
from models import CNN_Model, CNN_Model_Mode6

# %%
prefix = 'HIS'
weights_path = None 
model = CNN_Model_Mode6(weights_path=weights_path, train_flag=True, verbose=2,
                       nb_epoch=2, batch_size=64, 
                       prefix = prefix,
                       name = 'res_' + prefix, 
                       fname='../data/input_data.' + prefix + '.csv', f_out = '../data/output/output_data_mode5.csv')

model.train(sub_sample=True)
model.pred(get_last_layer=False)
# Out:
# Loading training data...
# (19634, 66) (19634, 66)
# 42 cols used: ['MutationAssessor_score_rankscore', 'VEST3_rankscore', 'Polyphen2_HDIV_rankscore', 'SIFT_converted_rankscore', 'PROVEAN_converted_rankscore', 'FATHMM_converted_rankscore', 'GenoCanyon_score_rankscore', 'LRT_converted_rankscore', 'Eigen-phred', 'phyloP20way_mammalian_rankscore', 'GERP++_RS_rankscore', 'SiPhy_29way_logOdds_rankscore', 'phastCons100way_vertebrate_rankscore', 'fathmm-MKL_coding_rankscore', 'phyloP100way_vertebrate_rankscore', 'phastCons20way_mammalian_rankscore', 'GM12878_fitCons_score_rankscore', 'HUVEC_fitCons_score_rankscore', 'integrated_fitCons_score_rankscore', 'H1-hESC_fitCons_score_rankscore', 'blosum62', 'pam250', 'SUMO_diff', 'SUMO_score', 'SUMO_cutoff', 'phospho_cutoff', 'phospho_score', 'phospho_diff', 's_het_log', 'secondary_E', 'secondary_H', 'complex_CORUM', 'preppi_counts', '1000Gp3_AF', 'ExAC_AF', 'gnomad', 'ASA', 'secondary_C', 'gc_content', 'interface', 'ubiquitination', 'BioPlex']
# ('X_train shape:', (31414, 42, 1, 1))
# (31414, 'train samples')
# (7854, 'test samples')
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input (InputLayer)               (None, 42, 1, 1)      0
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 42, 1, 32)     128         input[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 42, 1, 32)     3104        conv2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 42, 1, 32)     3104        conv2d_12[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 42, 1, 32)     0           conv2d_11[0][0]
#                                                                    conv2d_13[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 42, 1, 32)     0           merge_5[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 21, 1, 32)     0           activation_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 21, 1, 32)     3104        max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 21, 1, 32)     3104        conv2d_14[0][0]
# ____________________________________________________________________________________________________
# merge_6 (Merge)                  (None, 21, 1, 32)     0           max_pooling2d_5[0][0]
#                                                                    conv2d_15[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 21, 1, 32)     0           merge_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 10, 1, 32)     0           activation_6[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 320)           0           max_pooling2d_6[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 512)           164352      flatten_3[0][0]
# ____________________________________________________________________________________________________
# dense1 (Dense)                   (None, 1)             513         dense_3[0][0]
# ____________________________________________________________________________________________________
# act2 (Activation)                (None, 1)             0           dense1[0][0]
# ====================================================================================================
# Total params: 177,409
# Trainable params: 177,409
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None
# --------------------------------------------------
# Training...
# --------------------------------------------------
# Fitting  model...
# Train on 31414 samples, validate on 7854 samples
# Epoch 1/50
# Epoch 00000: val_loss improved from inf to 0.19851, saving model to ../models/resi_model_mode1-weights-improvement-00-0.92.hdf5
# 4s - loss: 0.5015 - acc: 0.8506 - val_loss: 0.1985 - val_acc: 0.9240
# Epoch 2/50
# Epoch 00001: val_loss improved from 0.19851 to 0.15411, saving model to ../models/resi_model_mode1-weights-improvement-01-0.94.hdf5
# 5s - loss: 0.1761 - acc: 0.9327 - val_loss: 0.1541 - val_acc: 0.9427
# Epoch 3/50
# Epoch 00002: val_loss did not improve
# 4s - loss: 0.1616 - acc: 0.9385 - val_loss: 0.1781 - val_acc: 0.9362
# Epoch 4/50
# Epoch 00003: val_loss did not improve
# 4s - loss: 0.1521 - acc: 0.9417 - val_loss: 0.1587 - val_acc: 0.9403
# Epoch 5/50
# Epoch 00004: val_loss improved from 0.15411 to 0.14604, saving model to ../models/resi_model_mode1-weights-improvement-04-0.94.hdf5
# 4s - loss: 0.1471 - acc: 0.9433 - val_loss: 0.1460 - val_acc: 0.9445
# Epoch 6/50
# Epoch 00005: val_loss improved from 0.14604 to 0.14469, saving model to ../models/resi_model_mode1-weights-improvement-05-0.95.hdf5
# 4s - loss: 0.1436 - acc: 0.9454 - val_loss: 0.1447 - val_acc: 0.9459
# Epoch 7/50
# Epoch 00006: val_loss improved from 0.14469 to 0.14203, saving model to ../models/resi_model_mode1-weights-improvement-06-0.95.hdf5
# 4s - loss: 0.1412 - acc: 0.9456 - val_loss: 0.1420 - val_acc: 0.9473
# Epoch 8/50
# Epoch 00007: val_loss did not improve
# 3s - loss: 0.1414 - acc: 0.9475 - val_loss: 0.1421 - val_acc: 0.9460
# Epoch 9/50
# Epoch 00008: val_loss improved from 0.14203 to 0.13927, saving model to ../models/resi_model_mode1-weights-improvement-08-0.95.hdf5
# 4s - loss: 0.1365 - acc: 0.9493 - val_loss: 0.1393 - val_acc: 0.9459
# Epoch 10/50
# Epoch 00009: val_loss did not improve
# 4s - loss: 0.1326 - acc: 0.9496 - val_loss: 0.1411 - val_acc: 0.9473
# Epoch 11/50
# Epoch 00010: val_loss improved from 0.13927 to 0.13883, saving model to ../models/resi_model_mode1-weights-improvement-10-0.95.hdf5
# 4s - loss: 0.1312 - acc: 0.9515 - val_loss: 0.1388 - val_acc: 0.9491
# Epoch 12/50
# Epoch 00011: val_loss did not improve
# 4s - loss: 0.1273 - acc: 0.9521 - val_loss: 0.1391 - val_acc: 0.9473
# Epoch 13/50
# Epoch 00012: val_loss did not improve
# 4s - loss: 0.1245 - acc: 0.9525 - val_loss: 0.1440 - val_acc: 0.9475
# Epoch 14/50
# Epoch 00013: val_loss did not improve
# 3s - loss: 0.1221 - acc: 0.9549 - val_loss: 0.1405 - val_acc: 0.9487
# Epoch 15/50
# Epoch 00014: val_loss did not improve
# 4s - loss: 0.1196 - acc: 0.9553 - val_loss: 0.1510 - val_acc: 0.9467
# Epoch 16/50
# Epoch 00015: val_loss did not improve
# 3s - loss: 0.1191 - acc: 0.9550 - val_loss: 0.1438 - val_acc: 0.9486
# Epoch 17/50
# Epoch 00016: val_loss did not improve
# 4s - loss: 0.1156 - acc: 0.9565 - val_loss: 0.1422 - val_acc: 0.9481
# Epoch 18/50
# Epoch 00017: val_loss did not improve
# 3s - loss: 0.1103 - acc: 0.9583 - val_loss: 0.1433 - val_acc: 0.9491
# Epoch 19/50
# Epoch 00018: val_loss improved from 0.13883 to 0.13785, saving model to ../models/resi_model_mode1-weights-improvement-18-0.95.hdf5
# 4s - loss: 0.1068 - acc: 0.9597 - val_loss: 0.1378 - val_acc: 0.9524
# Epoch 20/50
# Epoch 00019: val_loss did not improve
# 4s - loss: 0.1058 - acc: 0.9609 - val_loss: 0.1381 - val_acc: 0.9498
# Epoch 21/50
# Epoch 00020: val_loss did not improve
# 4s - loss: 0.1004 - acc: 0.9628 - val_loss: 0.1705 - val_acc: 0.9379
# Epoch 22/50
# Epoch 00021: val_loss did not improve
# 4s - loss: 0.0969 - acc: 0.9640 - val_loss: 0.1505 - val_acc: 0.9496
# Epoch 23/50
# Epoch 00022: val_loss did not improve
# 4s - loss: 0.0928 - acc: 0.9656 - val_loss: 0.1475 - val_acc: 0.9495
# Epoch 24/50
# Epoch 00023: val_loss did not improve
# 4s - loss: 0.0880 - acc: 0.9674 - val_loss: 0.1556 - val_acc: 0.9473
# Epoch 25/50
# Epoch 00024: val_loss did not improve
# 4s - loss: 0.0873 - acc: 0.9673 - val_loss: 0.1576 - val_acc: 0.9492
# Epoch 26/50
# Epoch 00025: val_loss did not improve
# 4s - loss: 0.0817 - acc: 0.9700 - val_loss: 0.1632 - val_acc: 0.9464
# Epoch 27/50
# Epoch 00026: val_loss did not improve
# 4s - loss: 0.0768 - acc: 0.9721 - val_loss: 0.1801 - val_acc: 0.9423
# Epoch 28/50
# Epoch 00027: val_loss did not improve
# 4s - loss: 0.0717 - acc: 0.9739 - val_loss: 0.1697 - val_acc: 0.9473
# Epoch 29/50
# Epoch 00028: val_loss did not improve
# 4s - loss: 0.0685 - acc: 0.9753 - val_loss: 0.1682 - val_acc: 0.9477
# Epoch 30/50
# Epoch 00029: val_loss did not improve
# 4s - loss: 0.0640 - acc: 0.9761 - val_loss: 0.2104 - val_acc: 0.9441
# Epoch 31/50
# Epoch 00030: val_loss did not improve
# 4s - loss: 0.0604 - acc: 0.9776 - val_loss: 0.1855 - val_acc: 0.9430
# Epoch 32/50
# Epoch 00031: val_loss did not improve
# 4s - loss: 0.0549 - acc: 0.9805 - val_loss: 0.1888 - val_acc: 0.9481
# Epoch 33/50
# Epoch 00032: val_loss did not improve
# 4s - loss: 0.0540 - acc: 0.9795 - val_loss: 0.1910 - val_acc: 0.9449
# Epoch 34/50
# Epoch 00033: val_loss did not improve
# 4s - loss: 0.0476 - acc: 0.9830 - val_loss: 0.2000 - val_acc: 0.9492
# Epoch 35/50
# Epoch 00034: val_loss did not improve
# 4s - loss: 0.0434 - acc: 0.9844 - val_loss: 0.2123 - val_acc: 0.9473
# Epoch 36/50
# Epoch 00035: val_loss did not improve
# 4s - loss: 0.0420 - acc: 0.9849 - val_loss: 0.2363 - val_acc: 0.9445
# Epoch 37/50
# Epoch 00036: val_loss did not improve
# 4s - loss: 0.0433 - acc: 0.9848 - val_loss: 0.2436 - val_acc: 0.9441
# Epoch 38/50
# Epoch 00037: val_loss did not improve
# 4s - loss: 0.0335 - acc: 0.9880 - val_loss: 0.2304 - val_acc: 0.9496
# Epoch 39/50
# Epoch 00038: val_loss did not improve
# 4s - loss: 0.0298 - acc: 0.9890 - val_loss: 0.2414 - val_acc: 0.9451
# Epoch 40/50
# Epoch 00039: val_loss did not improve
# 4s - loss: 0.0314 - acc: 0.9886 - val_loss: 0.2569 - val_acc: 0.9451
# Epoch 41/50
# Epoch 00040: val_loss did not improve
# 4s - loss: 0.0249 - acc: 0.9913 - val_loss: 0.2646 - val_acc: 0.9461
# Epoch 42/50
# Epoch 00041: val_loss did not improve
# 4s - loss: 0.0334 - acc: 0.9883 - val_loss: 0.2780 - val_acc: 0.9455
# Epoch 43/50
# Epoch 00042: val_loss did not improve
# 4s - loss: 0.0265 - acc: 0.9908 - val_loss: 0.2732 - val_acc: 0.9474
# Epoch 44/50
# Epoch 00043: val_loss did not improve
# 4s - loss: 0.0250 - acc: 0.9915 - val_loss: 0.2896 - val_acc: 0.9445
# Epoch 45/50
# Epoch 00044: val_loss did not improve
# 4s - loss: 0.0251 - acc: 0.9915 - val_loss: 0.2839 - val_acc: 0.9445
# Epoch 46/50
# Epoch 00045: val_loss did not improve
# 4s - loss: 0.0189 - acc: 0.9935 - val_loss: 0.2861 - val_acc: 0.9464
# Epoch 47/50
# Epoch 00046: val_loss did not improve
# 4s - loss: 0.0247 - acc: 0.9916 - val_loss: 0.3146 - val_acc: 0.9430
# Epoch 48/50
# Epoch 00047: val_loss did not improve
# 4s - loss: 0.0193 - acc: 0.9940 - val_loss: 0.3047 - val_acc: 0.9433
# Epoch 49/50
# Epoch 00048: val_loss did not improve
# 4s - loss: 0.0241 - acc: 0.9922 - val_loss: 0.2942 - val_acc: 0.9477
# Epoch 50/50
# Epoch 00049: val_loss did not improve
# 4s - loss: 0.0155 - acc: 0.9949 - val_loss: 0.3394 - val_acc: 0.9453
# ('Test score:', 0.339438513931274)
# ('Test accuracy:', 0.94525082761894696)
